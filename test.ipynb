# %%
with open('left.txt', 'r') as f:
    lines = f.readlines()

pack_l = []
for line_l in lines:
    
    pack_l.append(line_l.strip())
pack_l
# Out:
# ['absl-py              1.3.0',
#  'aiohttp              3.8.3',
#  'aiosignal            1.3.1',
#  'akro                 0.0.8',
#  'anyio                3.6.2',
#  'argon2-cffi          21.3.0',
#  'argon2-cffi-bindings 21.2.0',
#  'astor                0.8.1',
#  'async-timeout        4.0.2',
#  'asynctest            0.13.0',
#  'attrs                22.1.0',
#  'backcall             0.2.0',
#  'bcrypt               4.0.1',
#  'beautifulsoup4       4.11.1',
#  'bidict               0.22.1',
#  'bleach               6.0.0',
#  'certifi              2022.12.7',
#  'cffi                 1.15.1',
#  'charset-normalizer   2.1.1',
#  'click                8.1.3',
#  'cloudpickle          1.3.0',
#  'cma                  2.7.0',
#  'colorama             0.4.6',
#  'coverage             7.2.2',
#  'cryptography         38.0.3',
#  'cycler               0.11.0',
#  'debugpy              1.6.6',
#  'decorator            5.1.1',
#  'deepdiff             6.2.1',
# ...

# %%
with open('right.txt', 'r') as f:
    lines = f.readlines()

pack_r = []
for line_r in lines:
    
    pack_r.append(line_r.strip())
pack_r
# Out:
# ['attrs              22.2.0',
#  'backcall           0.2.0',
#  'bidict             0.22.1',
#  'certifi            2022.12.7',
#  'charset-normalizer 3.1.0',
#  'colorama           0.4.6',
#  'coverage           7.2.1',
#  'cycler             0.11.0',
#  'debugpy            1.5.1',
#  'decorator          5.1.1',
#  'dill               0.3.6',
#  'entrypoints        0.4',
#  'et-xmlfile         1.1.0',
#  'exceptiongroup     1.1.1',
#  'fonttools          4.38.0',
#  'idna               3.4',
#  'imageio            2.26.0',
#  'importlib-metadata 6.0.0',
#  'iniconfig          2.0.0',
#  'ipykernel          6.15.2',
#  'ipython            7.31.1',
#  'jedi               0.18.1',
#  'jupyter_client     7.4.9',
#  'jupyter_core       4.11.2',
#  'kiwisolver         1.4.4',
#  'matplotlib         3.5.3',
#  'matplotlib-inline  0.1.6',
#  'mock               5.0.1',
#  'multiprocess       0.70.14',
#  'MyQR               2.3.1',
#  'natnet             0.1.0',
# ...

# %%
for pr in pack_r:
    if pr in pack_l:
        pass
    else:
        print(pr)
# Out:
# attrs              22.2.0
# backcall           0.2.0
# bidict             0.22.1
# certifi            2022.12.7
# charset-normalizer 3.1.0
# colorama           0.4.6
# coverage           7.2.1
# cycler             0.11.0
# debugpy            1.5.1
# decorator          5.1.1
# dill               0.3.6
# entrypoints        0.4
# et-xmlfile         1.1.0
# exceptiongroup     1.1.1
# fonttools          4.38.0
# idna               3.4
# imageio            2.26.0
# importlib-metadata 6.0.0
# iniconfig          2.0.0
# ipykernel          6.15.2
# ipython            7.31.1
# jedi               0.18.1
# jupyter_client     7.4.9
# jupyter_core       4.11.2
# kiwisolver         1.4.4
# matplotlib         3.5.3
# matplotlib-inline  0.1.6
# mock               5.0.1
# multiprocess       0.70.14
# MyQR               2.3.1
# natnet             0.1.0
# nest-asyncio       1.5.6
# netaddr            0.8.0
# netifaces          0.11.0
# numpy              1.21.6
# opencv-python      4.7.0.72
# ...
